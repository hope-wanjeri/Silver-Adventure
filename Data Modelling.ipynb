# %%
# %pip install dbt-databricks

# %%
# %sh
dbt init Silver_Adventure

# %%
# %sh
# Move everything from the subfolder to your current location
mv Silver_adventure/* . 2>/dev/null || true
mv Silver_adventure/.* . 2>/dev/null || true

# Delete the now-empty subfolder
rmdir Silver_adventure 2>/dev/null || true


ls -F

# %%
# %sql
DESCRIBE workspace.default.nps_data

# %%
# %sql

DESCRIBE workspace.default.sales_credit_data

# %%
# %sh
# 2. Navigate to your project folder
cd /Workspace/Users/hopewanjeri0@gmail.com/Silver-Adventure/Silver_Adventure
dbt run --select credit_nps_analysis --profiles-dir .
